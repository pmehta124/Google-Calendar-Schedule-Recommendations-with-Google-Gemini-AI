# %% [markdown]
# # Google Calendar Retrieval

# %%
import webbrowser
urL='https://www.google.com'
chrome_path="C:\\Program Files (x86)\\Google\\Chrome\\Application\\chrome.exe"
webbrowser.register('chrome', None,webbrowser.BackgroundBrowser(chrome_path))
webbrowser.get('chrome').open_new_tab(urL)

# %%
# pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (2.117.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.17.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.29.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\palak\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pprint


import google.oauth2.credentials


from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow


pp = pprint.PrettyPrinter(indent=2)


# The CLIENT_SECRETS_FILE variable specifies the name of a file that contains
# the OAuth 2.0 information for this application, including its client_id and
# client_secret.
CLIENT_SECRETS_FILE = "credentials.json"


# This access scope grants read-only access to the authenticated user's Drive
# account.
SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']
API_SERVICE_NAME = 'calendar'
API_VERSION = 'v3'


def get_authenticated_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_local_server(port=10004)
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)


def list_drive_files(service, **kwargs):
  results = service.files().list(
    **kwargs
  ).execute()


  pp.pprint(results)


if __name__ == '__main__':
  # When running locally, disable OAuthlib's HTTPs verification. When
  # running in production *do not* leave this option enabled.
  os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
  service = get_authenticated_service()
  # list_drive_files(service,
  #                  orderBy='modifiedByMeTime desc',
  #                  pageSize=5)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=126442304783-s8mhkprh1g9tknkbqi11q4dccmjd8q84.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A10004%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar.readonly&state=PnZaifikG4kkA3XovI9JY6ZsZmagSc&access_type=offline

# %%
import datetime
from datetime import time
from datetime import timedelta

# %%
today = datetime.datetime.utcnow().replace(hour=0, minute=0, second=0, microsecond=0)
type(today)
# Out:
# datetime.datetime

# %%
today = today + datetime.timedelta(days=-3)
today
# Out:
# datetime.datetime(2024, 2, 8, 0, 0)

# %%
today = today.isoformat("T") + "Z"

# %%
work = today.isoformat("T")
work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 work = today.isoformat("T")
#       2 work
#
# AttributeError: 'str' object has no attribute 'isoformat'

# %%
today = datetime.datetime.now().isoformat("T")
service.events().list(calendarId='primary', orderBy = 'startTime', singleEvents=True, timeMin=now).execute()
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p33g8b7u5oih880o"',
#  'summary': 'palak.mehta272@gmail.com',
#  'description': '',
#  'updated': '2024-02-11T05:17:56.236Z',
#  'timeZone': 'America/New_York',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#  'nextPageToken': 'EiwKKhIoCgYI6PO_sQYSHgocChptMDZvZXU0ZTMzbzAzY3ZoZThndWplZzFmb8A-AQ==',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3411723490498000"',
#    'id': 'b46g25gmh96fth516421n2l2us_20240211T130000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=
wMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2023-09-05T21:22:48.000Z',
#    'updated': '2023-12-02T22:54:09.999Z',
#    'summary': 'CANCEL SPOTIFY',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-25T18:00:00-05:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-02-25T21:00:00-05:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'v3mbbjo8o5a9poqfn8ssvvmv94',
#    'originalStartTime': {'dateTime': '2024-02-25T18:00:00-05:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'v3mbbjo8o5a9poqfn8ssvvmv94@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550289678000"',
#    'id': 'tmuou0qm8prq8kblam22ge74lc_20240226T152000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dG11b3UwcW04cHJxOGtibGFtMjJnZTc0bGNfMjAyNDAyMjZUMTUyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:29:03.000Z',
#    'updated': '2024-01-14T23:32:24.839Z',
#    'summary': 'Jainism class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-26T10:20:00-05:00',
# ...
#    'id': 'k8nojih5ele7eg6kra5rlto98s_20240423T195000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=azhub2ppaDVlbGU3ZWc2a3JhNXJsdG85OHNfMjAyNDA0MjNUMTk1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:48:03.000Z',
#    'updated': '2024-01-14T23:48:44.219Z',
#    'summary': 'Bdauu class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-23T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-23T17:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'k8nojih5ele7eg6kra5rlto98s',
#    'originalStartTime': {'dateTime': '2024-04-23T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'k8nojih5ele7eg6kra5rlto98s@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3412219496084000"',
#    'id': '1iqump8ia7c8h1mnn9pbc331bo_20240424T000000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWlxdW1wOGlhN2M4aDFtbm45cGJjMzMxYm9fMjAyNDA0MjRUMDAwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-24T15:22:28.000Z',
#    'updated': '2024-01-24T15:22:28.042Z',
#    'summary': 'CUBITS',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-23T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-23T22:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': '1iqump8ia7c8h1mnn9pbc331bo',
#    'originalStartTime': {'dateTime': '2024-04-23T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': '1iqump8ia7c8h1mnn9pbc331bo@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3409369964492000"',
#    'id': 'mb9pspkqmffglth1lnj15j5t5s_20240424T120000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bWI5cHNwa3FtZmZnbHRoMWxuajE1ajV0NXNfMjAyNDA0MjRUMTIwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-08T03:36:22.000Z',
#    'updated': '2024-01-08T03:36:22.246Z',
#    'summary': 'WORK',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-24T08:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-24T18:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'mb9pspkqmffglth1lnj15j5t5s',
#    'originalStartTime': {'dateTime': '2024-04-24T08:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'mb9pspkqmffglth1lnj15j5t5s@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552620782000"',
#    'id': 'm06oeu4e33o03cvhe8gujeg1fo_20240424T195000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bTA2b2V1NGUzM28wM2N2aGU4Z3VqZWcxZm9fMjAyNDA0MjRUMTk1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:51:33.000Z',
#    'updated': '2024-01-14T23:51:50.391Z',
#    'summary': 'data science class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-24T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-24T17:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'm06oeu4e33o03cvhe8gujeg1fo',
#    'originalStartTime': {'dateTime': '2024-04-24T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'm06oeu4e33o03cvhe8gujeg1fo@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552772170000"',
#    'id': 'l09te109c07acbh9b539me8ae4_20240424T234500Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bDA5dGUxMDljMDdhY2JoOWI1MzltZThhZTRfMjAyNDA0MjRUMjM0NTAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:53:06.000Z',
#    'updated': '2024-01-14T23:53:06.085Z',
#    'summary': 'data science recitation',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-24T19:45:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-24T20:45:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'l09te109c07acbh9b539me8ae4',
#    'originalStartTime': {'dateTime': '2024-04-24T19:45:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'l09te109c07acbh9b539me8ae4@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3412219496084000"',
#    'id': '1iqump8ia7c8h1mnn9pbc331bo_20240425T000000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWlxdW1wOGlhN2M4aDFtbm45cGJjMzMxYm9fMjAyNDA0MjVUMDAwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-24T15:22:28.000Z',
#    'updated': '2024-01-24T15:22:28.042Z',
#    'summary': 'CUBITS',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-24T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-24T22:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': '1iqump8ia7c8h1mnn9pbc331bo',
#    'originalStartTime': {'dateTime': '2024-04-24T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': '1iqump8ia7c8h1mnn9pbc331bo@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550289678000"',
#    'id': 'tmuou0qm8prq8kblam22ge74lc_20240425T142000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dG11b3UwcW04cHJxOGtibGFtMjJnZTc0bGNfMjAyNDA0MjVUMTQyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:29:03.000Z',
#    'updated': '2024-01-14T23:32:24.839Z',
#    'summary': 'Jainism class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-25T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-25T11:40:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'tmuou0qm8prq8kblam22ge74lc',
#    'originalStartTime': {'dateTime': '2024-04-25T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'tmuou0qm8prq8kblam22ge74lc@google.com',
#    'sequence': 2,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550703234000"',
#    'id': 'ff653vl50jjfr1ef05l81c8630_20240425T161000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=ZmY2NTN2bDUwampmcjFlZjA1bDgxYzg2MzBfMjAyNDA0MjVUMTYxMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:35:51.000Z',
#    'updated': '2024-01-14T23:35:51.617Z',
#    'summary': 'Stat Meth class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-25T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-25T13:30:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'ff653vl50jjfr1ef05l81c8630',
#    'originalStartTime': {'dateTime': '2024-04-25T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'ff653vl50jjfr1ef05l81c8630@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552248438000"',
#    'id': 'k8nojih5ele7eg6kra5rlto98s_20240425T195000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=azhub2ppaDVlbGU3ZWc2a3JhNXJsdG85OHNfMjAyNDA0MjVUMTk1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:48:03.000Z',
#    'updated': '2024-01-14T23:48:44.219Z',
#    'summary': 'Bdauu class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-25T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-25T17:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'k8nojih5ele7eg6kra5rlto98s',
#    'originalStartTime': {'dateTime': '2024-04-25T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'k8nojih5ele7eg6kra5rlto98s@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3412219496084000"',
#    'id': '1iqump8ia7c8h1mnn9pbc331bo_20240426T000000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWlxdW1wOGlhN2M4aDFtbm45cGJjMzMxYm9fMjAyNDA0MjZUMDAwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-24T15:22:28.000Z',
#    'updated': '2024-01-24T15:22:28.042Z',
#    'summary': 'CUBITS',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-25T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-25T22:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': '1iqump8ia7c8h1mnn9pbc331bo',
#    'originalStartTime': {'dateTime': '2024-04-25T20:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': '1iqump8ia7c8h1mnn9pbc331bo@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3413702515888000"',
#    'id': '6lrbqevk8ue47a3qjfh7q5nr34_20240426T120000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=NmxyYnFldms4dWU0N2EzcWpmaDdxNW5yMzRfMjAyNDA0MjZUMTIwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2023-12-09T22:04:14.000Z',
#    'updated': '2024-02-02T05:20:57.944Z',
#    'summary': 'WORK in person?',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-26T08:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-26T18:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': '6lrbqevk8ue47a3qjfh7q5nr34',
#    'originalStartTime': {'dateTime': '2024-04-26T08:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': '6lrbqevk8ue47a3qjfh7q5nr34@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550388090000"',
#    'id': 'vl6kgnn821vihlcnnf73tj3s4d_20240426T142000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dmw2a2dubjgyMXZpaGxjbm5mNzN0ajNzNGRfMjAyNDA0MjZUMTQyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:32:04.000Z',
#    'updated': '2024-01-14T23:33:14.045Z',
#    'summary': 'Business Data Management class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-26T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-26T11:40:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'vl6kgnn821vihlcnnf73tj3s4d',
#    'originalStartTime': {'dateTime': '2024-04-26T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'vl6kgnn821vihlcnnf73tj3s4d@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3411036720794000"',
#    'id': 'qi7isrfc60qorp3b43m80homls',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=cWk3aXNyZmM2MHFvcnAzYjQzbTgwaG9tbHMgcGFsYWsubWVodGEyNzJAbQ',
#    'created': '2024-01-17T19:05:20.000Z',
#    'updated': '2024-01-17T19:06:00.397Z',
#    'summary': 'Riya’s Parents Anniversary Party -Foregate Country Club',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-27T18:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-27T21:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'qi7isrfc60qorp3b43m80homls@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550289678000"',
#    'id': 'tmuou0qm8prq8kblam22ge74lc_20240429T142000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dG11b3UwcW04cHJxOGtibGFtMjJnZTc0bGNfMjAyNDA0MjlUMTQyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:29:03.000Z',
#    'updated': '2024-01-14T23:32:24.839Z',
#    'summary': 'Jainism class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T11:40:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'tmuou0qm8prq8kblam22ge74lc',
#    'originalStartTime': {'dateTime': '2024-04-29T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'tmuou0qm8prq8kblam22ge74lc@google.com',
#    'sequence': 2,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550703234000"',
#    'id': 'ff653vl50jjfr1ef05l81c8630_20240429T161000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=ZmY2NTN2bDUwampmcjFlZjA1bDgxYzg2MzBfMjAyNDA0MjlUMTYxMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:35:51.000Z',
#    'updated': '2024-01-14T23:35:51.617Z',
#    'summary': 'Stat Meth class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T13:30:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'ff653vl50jjfr1ef05l81c8630',
#    'originalStartTime': {'dateTime': '2024-04-29T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'ff653vl50jjfr1ef05l81c8630@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552620782000"',
#    'id': 'm06oeu4e33o03cvhe8gujeg1fo_20240429T195000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bTA2b2V1NGUzM28wM2N2aGU4Z3VqZWcxZm9fMjAyNDA0MjlUMTk1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:51:33.000Z',
#    'updated': '2024-01-14T23:51:50.391Z',
#    'summary': 'data science class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T17:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'm06oeu4e33o03cvhe8gujeg1fo',
#    'originalStartTime': {'dateTime': '2024-04-29T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'm06oeu4e33o03cvhe8gujeg1fo@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %% [markdown]
# today = datetime.datetime.now().isoformat("T")
# service.events().list(calendarId='primary', orderBy = 'startTime', singleEvents=True, timeMin=today).execute()

# %%
import datetime
from datetime import time
from datetime import timedelta
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 why = today.isoformat("T") + "Z"
#
# AttributeError: 'str' object has no attribute 'isoformat'

# %%
today = datetime.datetime.today()

# Calculate three days ago
three_days_ago = today - datetime.timedelta(days=3)

# Format the datetime object in RFC3339 format
rfc3339_format = three_days_ago.isoformat("T")

# %%
rfc3339_format
# Out:
# '2024-02-08T02:27:22.914385'

# %%
now = datetime.datetime.utcnow().isoformat() + "Z"

# %%
today = datetime.datetime.now().isoformat("T")

now = datetime.datetime.utcnow().isoformat() + "Z"

service.events().list(calendarId='primary', orderBy = 'startTime', singleEvents=True, timeMin=now).execute()
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p33g8b7u5oih880o"',
#  'summary': 'palak.mehta272@gmail.com',
#  'description': '',
#  'updated': '2024-02-11T05:17:56.236Z',
#  'timeZone': 'America/New_York',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#  'nextPageToken': 'EiwKKhIoCgYI6PO_sQYSHgocChptMDZvZXU0ZTMzbzAzY3ZoZThndWplZzFmb8A-AQ==',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3411723490498000"',
#    'id': 'b46g25gmh96fth516421n2l2us_20240211T130000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=YjQ2ZzI1Z21oOTZmdGg1MTY0MjFuMmwydXNfMjAyNDAyMTFUMTMwMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01
google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550388090000"',
#    'id': 'vl6kgnn821vihlcnnf73tj3s4d_20240426T142000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dmw2a2dubjgyMXZpaGxjbm5mNzN0ajNzNGRfMjAyNDA0MjZUMTQyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:32:04.000Z',
#    'updated': '2024-01-14T23:33:14.045Z',
#    'summary': 'Business Data Management class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-26T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-26T11:40:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'vl6kgnn821vihlcnnf73tj3s4d',
#    'originalStartTime': {'dateTime': '2024-04-26T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'vl6kgnn821vihlcnnf73tj3s4d@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3411036720794000"',
#    'id': 'qi7isrfc60qorp3b43m80homls',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=cWk3aXNyZmM2MHFvcnAzYjQzbTgwaG9tbHMgcGFsYWsubWVodGEyNzJAbQ',
#    'created': '2024-01-17T19:05:20.000Z',
#    'updated': '2024-01-17T19:06:00.397Z',
#    'summary': 'Riya’s Parents Anniversary Party -Foregate Country Club',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-27T18:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-27T21:00:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'qi7isrfc60qorp3b43m80homls@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550289678000"',
#    'id': 'tmuou0qm8prq8kblam22ge74lc_20240429T142000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dG11b3UwcW04cHJxOGtibGFtMjJnZTc0bGNfMjAyNDA0MjlUMTQyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:29:03.000Z',
#    'updated': '2024-01-14T23:32:24.839Z',
#    'summary': 'Jainism class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T11:40:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'tmuou0qm8prq8kblam22ge74lc',
#    'originalStartTime': {'dateTime': '2024-04-29T10:20:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'tmuou0qm8prq8kblam22ge74lc@google.com',
#    'sequence': 2,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550703234000"',
#    'id': 'ff653vl50jjfr1ef05l81c8630_20240429T161000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=ZmY2NTN2bDUwampmcjFlZjA1bDgxYzg2MzBfMjAyNDA0MjlUMTYxMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:35:51.000Z',
#    'updated': '2024-01-14T23:35:51.617Z',
#    'summary': 'Stat Meth class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T13:30:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'ff653vl50jjfr1ef05l81c8630',
#    'originalStartTime': {'dateTime': '2024-04-29T12:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'ff653vl50jjfr1ef05l81c8630@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552620782000"',
#    'id': 'm06oeu4e33o03cvhe8gujeg1fo_20240429T195000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bTA2b2V1NGUzM28wM2N2aGU4Z3VqZWcxZm9fMjAyNDA0MjlUMTk1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:51:33.000Z',
#    'updated': '2024-01-14T23:51:50.391Z',
#    'summary': 'data science class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-04-29T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-04-29T17:10:00-04:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'm06oeu4e33o03cvhe8gujeg1fo',
#    'originalStartTime': {'dateTime': '2024-04-29T15:50:00-04:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'm06oeu4e33o03cvhe8gujeg1fo@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %%
now = datetime.datetime.utcnow()

# %%
yesterday = now - datetime.timedelta(days=1)
yesterday
# Out:
# datetime.datetime(2024, 2, 10, 7, 32, 20, 735545)

# %%
today = yesterday.isoformat("T")
service.events().list(calendarId='primary', orderBy = 'startTime', singleEvents=True, timeMin=today).execute()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[101], line 2
#       1 today = yesterday.isoformat("T")
# ----> 2 service.events().list(calendarId='primary', orderBy = 'startTime', singleEvents=True, timeMin=today).execute()
#
# File c:\Users\palak\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\palak\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://www.googleapis.com/calendar/v3/calendars/primary/events?orderBy=startTime&singleEvents=true&timeMin=2024-02-10T07%3A32%3A20.735545&alt=json returned "Bad Request". Details: "[{'domain': 'global', 'reason': 'badRequest', 'message': 'Bad Request'}]">

# %%
currentDay = datetime.datetime.utcnow()
currentDay = currentDay - datetime.timedelta(days=3)
currentDay = currentDay.isoformat() + "Z"

nextDay = datetime.datetime.utcnow()
nextDay = nextDay - datetime.timedelta(days=2)
nextDay = nextDay.isoformat() + "Z"

print(currentDay)
print(nextDay)
eventDict = service.events().list(calendarId='primary', orderBy='startTime', singleEvents=True, timeMin=currentDay, timeMax=nextDay).execute()
eventDict
# Out:
# 2024-02-08T07:38:12.435912Z
# 2024-02-09T07:38:12.435912Z
# {'kind': 'calendar#events',
#  'etag': '"p33g8b7u5oih880o"',
#  'summary': 'palak.mehta272@gmail.com',
#  'description': '',
#  'updated': '2024-02-11T05:17:56.236Z',
#  'timeZone': 'America/New_York',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3410550289678000"',
#    'id': 'tmuou0qm8prq8kblam22ge74lc_20240208T152000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=dG11b3UwcW04cHJxOGtibGFtMjJnZTc0bGNfMjAyNDAyMDhUMTUyMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:29:03.000Z',
#    'updated': '2024-01-14T23:32:24.839Z',
#    'summary': 'Jainism class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-08T10:20:00-05:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-02-08T11:40:00-05:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'tmuou0qm8prq8kblam22ge74lc',
#    'originalStartTime': {'dateTime': '2024-02-08T10:20:00-05:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'tmuou0qm8prq8kblam22ge74lc@google.com',
#    'sequence': 2,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410550703234000"',
#    'id': 'ff653vl50jjfr1ef05l81c8630_20240208T171000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=ZmY2NTN2bDUwampmcjFlZjA1bDgxYzg2MzBfMjAyNDAyMDhUMTcxMDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:35:51.000Z',
#    'updated': '2024-01-14T23:35:51.617Z',
#    'summary': 'Stat Meth class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-08T12:10:00-05:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-02-08T13:30:00-05:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'ff653vl50jjfr1ef05l81c8630',
#    'originalStartTime': {'dateTime': '2024-02-08T12:10:00-05:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'ff653vl50jjfr1ef05l81c8630@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3410552248438000"',
#    'id': 'k8nojih5ele7eg6kra5rlto98s_20240208T205000Z',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=azhub2ppaDVlbGU3ZWc2a3JhNXJsdG85OHNfMjAyNDAyMDhUMjA1MDAwWiBwYWxhay5tZWh0YTI3MkBt',
#    'created': '2024-01-14T23:48:03.000Z',
#    'updated': '2024-01-14T23:48:44.219Z',
#    'summary': 'Bdauu class',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-08T15:50:00-05:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-02-08T17:10:00-05:00',
#     'timeZone': 'America/New_York'},
#    'recurringEventId': 'k8nojih5ele7eg6kra5rlto98s',
#    'originalStartTime': {'dateTime': '2024-02-08T15:50:00-05:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'k8nojih5ele7eg6kra5rlto98s@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3415257352472000"',
#    'id': 'egj2593vuqh5d6labsg1qt7ue8',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=ZWdqMjU5M3Z1cWg1ZDZsYWJzZzFxdDd1ZTggcGFsYWsubWVodGEyNzJAbQ',
#    'created': '2024-01-18T07:18:38.000Z',
#    'updated': '2024-02-11T05:17:56.236Z',
#    'summary': 'Tutor Ben ',
#    'creator': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'organizer': {'email': 'palak.mehta272@gmail.com', 'self': True},
#    'start': {'dateTime': '2024-02-08T17:30:00-05:00',
#     'timeZone': 'America/New_York'},
#    'end': {'dateTime': '2024-02-08T18:30:00-05:00',
#     'timeZone': 'America/New_York'},
#    'iCalUID': 'egj2593vuqh5d6labsg1qt7ue8@google.com',
#    'sequence': 1,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %%
schedule = {}

# date = eventDict['items'][0]["start"]["dateTime"]
# formatted_date = datetime.datetime.strftime(date, "%m-%d-%Y")
# print(formatted_date)


for i in eventDict['items']:

    start = i["start"]["dateTime"]
    startNow = datetime.datetime.strptime(start, '%Y-%m-%dT%H:%M:%S%z').time()
    startNowFormat = startNow.strftime("%I:%M %p")


    end = i["end"]["dateTime"]
    endNow = datetime.datetime.strptime(end, '%Y-%m-%dT%H:%M:%S%z').time()
    endNowFormat = endNow.strftime("%I:%M %p")

    schedule[i['summary']] = [startNowFormat, endNowFormat]

# %%
schedule
# Out:
# {'Jainism class': ['10:20 AM', '11:40 AM'],
#  'Stat Meth class': ['12:10 PM', '01:30 PM'],
#  'Bdauu class': ['03:50 PM', '05:10 PM'],
#  'Tutor Ben ': ['05:30 PM', '06:30 PM']}

# %% [markdown]
# # GenAI Gemini Flow

# %%
# !pip install -q -U google-generativeai
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
genai.configure(api_key="AIzaSyD4HW-6nwpKi1nlFmlZyJa56HJ4WmWLY-8")

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content(f'''This is my schedule {schedule}. I wake up at 8:00 AM and sleep at 10:00 PM. First, keep the provided schedule as it is. Then, add new events to the schedule that will make the day better for my mental health and reduce stress. Make sure the new events do not overlap in time with any old events. Make sure there are at least 15 minutes between each event.  Print out the new schedule in a readable format and in order of time.''')

# %%
updatedSchedule = to_markdown(response.text)

# %%
updatedSchedule
# Out:
# > 8:00 AM - Wake up
# >
# > 9:00 AM - Morning Walk/Exercise (30 minutes)
# >
# > 9:30 AM - Breakfast and Journaling (30 minutes)
# >
# > 10:20 AM - Jainism class (80 minutes)
# >
# > 11:40 AM - Stretch break (15 minutes)
# >
# > 12:10 PM - Stat Meth class (80 minutes)
# >
# > 01:30 PM - Lunch break (30 minutes)
# >
# > 02:00 PM - Power nap (30 minutes)
# >
# > 03:50 PM - Bdauu class (80 minutes)
# >
# > 05:10 PM - Break and Snack (15 minutes)
# >
# > 05:30 PM - Tutor Ben (60 minutes)
# >
# > 06:30 PM - Dinner and Relaxation (60 minutes)
# >
# > 07:30 PM - Yoga/Meditation (30 minutes)
# >
# > 08:00 PM - Leisure time (reading, hobbies, etc.)
# >
# > 10:00 PM - Sleep

# %%
response = model.generate_content(f'''Here is my schedule {schedule}. 

You are a bot that takes in this schedule. Do not change the time of any of the events. Add new events that would help with an employee's mental health and reduce stress. Make sure the new events do not conflict in time with the old events. Below, give the updated schedule in a table, sorted by start time, and DO NOT WRITE ANYTHING ELSE.''')

# %%
NEW = to_markdown(response.text)

# %%
NEW
# Out:
# > | Event | Time |
# > | --- | --- |
# > | Jainism class | 10:20 AM - 11:40 AM |
# > | Stat Meth class | 12:10 PM - 01:30 PM |
# > | Lunch break | 01:30 PM - 03:50 PM |
# > | Bdauu class | 03:50 PM - 05:10 PM |
# > | Short walk | 05:10 PM - 05:30 PM |
# > | Tutor Ben  | 05:30 PM - 06:30 PM |
# > | Meditation | 06:30 PM - 07:00 PM |
